# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train=pd.read_csv('data/train.csv')

# %%
sns.catplot(data=train,x="Embarked",y='Age',kind='box',hue='Sex',aspect=4)
